# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Module Title:
# 	 Artificial Intelligence
# # Assessment Title:
# 	 AI_Lv8_CA2_v8
# # Lecturer Name:
# 	 David McQuaid
# # Student Full Name:
# 	 Lais Ferreira dos Santos
# # Student Number:
#      2020311
# # Assessment Due Date:
# 	 19/11/2023
# # Date of Submission:

# %% [markdown]
# # Questions
#
# 1.	A puzzle has multiple ways of reaching the end solution. Fig. 1 shows a graph that represents all possible routes to the solution. The starting point of the game is represented by A, the solution is represented by S. The other points in the graph are possible intermediary stages.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # (a)	The graph in Fig. 1 is a visualisation of the problem.
#
#    (i)	 Identify the differences between a graph and a tree. [0-5]
#    1. Connectivity and Acyclicity:
#
#        Graphs: Can be connected or disconnected, and cycles are allowed.
#        Trees: Must be connected, and cycles are not allowed.
#
#
#    2. Path Uniqueness:
#
#        Graphs: No restriction on the uniqueness of paths between vertices.
#        Trees: Unique path between any two vertices.
#
#
#    3. Root Nodes:
#
#        Graphs: Can have multiple root nodes or node at all.
#        Trees: Must have a single root node from which all other nodes are reachable.
#
#
#    4. Children:
#
#        Graphs: Nodes can have any number of edges.
#        Trees: In a binary tree, each node has at least two children. In a non-binary tree, each node can have any number of children.
#
#
#   The distinctions between graphs and trees, lie in the connectivity, acyclicity, ordering, and the presence of a single root in the trees. Trees impose a more structured and hierarchical relationship among vertices compared to the more flexible and diverse relationships in graphs.
#
#    (ii)  Explain in detail how the graph is an abstraction of the problem. [0-5]
#
#    The graph is an abstraction of the problem because it simplifies the problem by focusing on the relationships between objects and ignoring other details, and modeling a real-world problem by spliting the problem in a set of connected nodes.
#    We can use graph algoriths to find the shortest path between the start point (A), to the end (S).
#
#    (iii) Identify the advantages of using a visualisation such as the one shown in Fig. 1. [0-5]
#
#    The graph presented is a weighted graph, where the edges possess numerical properties essential for algorithms to solve problems. These weights can denote cost, distance, or other secific measurement units.
#    One of the key advantages of the graph's viasualisation as a weighted graph lies in its accuracy in pathfinding.
#    Additionally, it enables the visualisatio and exploration of connections between the nodes, accelerating investigations.

# %% [markdown]
# # (b)	Demonstrate how Dijkstra’s algorithm would find the shortest path to the solution in Fig.1 through diagrams and written explanation of each stage. [0-25]

# %% [markdown]
# Dijkstra's algorithm is usually used for solving shortest pathing problems having non-negative edge weight in the graphs[1].
# The algorithm keeps a set of visited vertices and a set of unvisited vertices. It starts at the node A and selects the unvisited vertex with the smallest tentative distance from the start node. It then visits the neighboors of this vertex and updates their tentative distances if a short path is found.
# I will walk you through to the steps, explaining how to find the shortest path between the vertex A and the solution, which is S.
# 1. I assigned the tentative distance of 0 to A which is the start vertex, and for the other I assigned infinity.
# 2. The vertex A is marked as visited and added to the set of visited vertices, and a priority queue is created with the initial distances (0, 'A').
# 3. The tentative of disntaces of all neighbors of A are updates. A to B is 1, A to C is 5, and A to H is 2.
# 4. I selected the smallest unvisited, which is B. I marked as visited and added to the set of visited vertices. the priority queue now is [(2, 'H'), (3, 'C'), (5, 'D')].
# 5. The next smallest path is H, and the priority queue updated is (7, 'K'), (11, 'J')].
# 6. 'C' is the the follow node with the smallest distance, the priority queue is [(5, 'D'), (7, 'K'), (9, 'E'), (11, 'J'), (4, 'G')].
# 7. 'D' is now the smallest path, the priority queue is [(7, 'K'), (8, 'E'), (11, 'J'), (12, 'F'), (12, 'L'), (4, 'G')].
# 8. Node 'G' will be the next smallest distance and the priority queue is Priority Queue: [(8, 'E'), (10, 'F'), (11, 'J'), (12, 'L'), (4, 'G')].
# 9. 'E' is the next node with the smallest distance, the priority queue is [(10, 'F'), (11, 'J'), (12, 'L'), (16, 'M')].
# 10. Node 'F', priority queue [(11, 'J'), (12, 'L'), (12, 'M')].
# 11. Node 'J', priority queue [(12, 'L'), (12, 'M'), (17, 'N')].
# These steps will continue until the solution is reached, or until all the reachable vertices have been visited.
# ![Diagram-2.png](attachment:Diagram-2.png)

# %% [markdown]
# # 2. The creator of the puzzle has been told that the A* algorithm is more efficient at finding the shortest path because it uses heuristics. Compare the performance of Dijkstra’s algorithm and the A* search algorithm, referring to heuristics, to find the shortest path to the problem by implementing both algorithms programmatically and comparing the solutions generated in Mark-down. Refer to the complexity of the algorithms and compare the actual time it takes for the solutions to be processed. [0-60]

# %%
#import the heap module
import heapq

#the 'calculate' function gets the distance
#between the start and the other vertices
def calculate(graph, start):
    #creates 'distances' dictionary, that assigns infinity as initial
    #value to each vertex
    distances = {vertex: float('infinity') for vertex in graph}
    #sets 'o' as the distance of the starting vertex
    distances[start] = 0
    
    #the priority queue keeps track of
    #the nodes with the smallest distance
    #from the staring node
    priority_queue = [(0, start)]
    while len(priority_queue) > 0:
        current_distance, current_vertex = heapq.heappop(priority_queue)

        # Nodes can get added to the priority queue multiple times. We only
        # process a vertex the first time we remove it from the priority queue.
        if current_distance > distances[current_vertex]:
            continue

        for neighbor, weight in graph[current_vertex].items():
            distance = current_distance + weight

            # Only consider this new path if it's better than any path we've
            # already found.
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                heapq.heappush(priority_queue, (distance, neighbor))
  
    # Returns all the shortest paths
    return distances

graph = {
    'A': {'B': 1, 'C': 5, 'H': 2},
    'B': {'A': 1, 'C': 2, 'D': 4},
    'C': {'A': 5, 'B': 2, 'G': 1},
    'D': {'B': 4, 'F': 7, 'E': 4, 'L': 7},
    'E': {'D': 4, 'F': 3, 'W': 6},
    'F': {'G': 2, 'D': 7, 'E': 3},
    'G': {'C': 1, 'L': 3, 'F': 2},
    'H': {'A': 2, 'K': 5, 'J': 9},
    'J': {'H': 9, 'K': 3, 'N': 6},
    'K': {'H': 5, 'L': 5, 'J': 3},
    'L': {'G': 3, 'D': 7, 'K': 5, 'N': 3, 'M': 4, 'V': 10, 'W': 8},
    'M': {'L': 4, 'P': 2, 'Q': 10},
    'N': {'J': 6, 'L': 3, 'S': 7, 'P': 4},
    'P': {'N': 4, 'R': 5, 'M': 2},
    'Q': {'M': 10, 'S': 8, 'W': 4},
    'R': {'P': 5, 'T': 3, 'S': 4},
    'S': {'N': 7, 'R': 4, 'T': 4, 'U': 2, 'V': 6, 'Q': 8},
    'T': {'R': 3, 'S': 4, 'U': 1},
    'U': {'T': 1, 'S': 2, 'V': 3},
    'V': {'W': 5, 'L': 10, 'S': 6, 'U': 3},
    'W': {'E': 6, 'L': 8, 'Q': 4, 'V': 5}
}

print(calculate(graph, 'S'))

# %% [markdown]
# # References
#
# https://www.geeksforgeeks.org/difference-between-graph-and-tree/
# https://linkurious.com/blog/why-graph-visualization-matters/
# https://www.geeksforgeeks.org/heap-queue-or-heapq-in-python/
# https://www.geeksforgeeks.org/introduction-to-dijkstras-shortest-path-algorithm/  [1]
# https://www.tutorialspoint.com/dijkstra-s-algorithm-to-compute-the-shortest-path-through-a-graph
